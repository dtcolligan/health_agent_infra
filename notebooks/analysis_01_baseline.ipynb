# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../data/model/daily_features.csv")

df.head()

# %%
import sys
print(sys.executable)
# Out:
# /workspaces/garmin_lab/.venv/bin/python
